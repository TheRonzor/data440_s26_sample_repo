# %%
from src.data import make_data, save_data, load_data

# %%
data = make_data()

# %%
#data

# %%
save_data(data, 'test_data.npy')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 save_data(data, 'test_data.npy')
#
# File ~/Desktop/WM2/data440_s26_sample_repo/src/data.py:31, in save_data(data, filename)
#      29 # Don't overwrite an existing file
#      30 if os.path.exists(full_filename):
# ---> 31     raise FileExistsError(f'file {full_filename} already exists.')
#      33 # Save the array as a .npy file
#      34 np.save(full_filename, data)
#
# FileExistsError: file data/test_data.npy already exists.

# %%
data2 = load_data('test_data.npy')
data2
# Out:
# array([[22, 20],
#        [19, 21],
#        [17, 20],
#        [24, 20],
#        [22, 13],
#        [17, 16],
#        [20,  4],
#        [23, 12],
#        [ 8, 18],
#        [19,  9],
#        [18, 15],
#        [11, 15],
#        [ 5,  0],
#        [ 2, 19],
#        [12,  8],
#        [10,  3],
#        [23, 20],
#        [ 7,  3],
#        [ 2, 12],
#        [ 7, 20],
#        [20, 20],
#        [17,  6],
#        [20,  1],
#        [15, 12],
#        [ 2,  2],
#        [ 6, 13],
#        [20, 21],
#        [ 5,  8],
#        [ 7,  4],
#        [12, 22],
#        [ 3,  3],
#        [16, 21],
#        [ 5,  1],
#        [ 2, 22],
#        [13,  4],
#        [20,  4],
#        [17, 17],
#        [16, 22],
#        [18,  4],
#        [ 2, 17],
#        [23, 20],
#        [ 6, 16],
#        [20, 21],
#        [ 1,  2],
#        [ 9, 11],
#        [12, 25],
#        [ 1, 18],
#        [15,  2],
#        [24,  3],
#        [17, 16],
#        [18, 18],
#        [ 3, 19],
#        [13,  6],
#        [ 8,  7],
#        [17,  4],
#        [24, 18],
#        [15,  4],
#        [ 0,  7],
#        [ 7, 18],
#        [19, 24],
#        [14, 24],
#        [17, 24],
#        [ 2,  8],
#        [17, 18],
#        [ 7, 24],
#        [10, 19],
#        [11,  8],
#        [16, 11],
#        [ 8, 11],
#        [14,  4],
#        [22,  0],
#        [25, 10],
#        [24,  6],
#        [ 2, 15],
#        [ 2,  0],
#        [ 9,  8],
#        [12,  7],
#        [11, 23],
#        [ 4, 19],
#        [25, 20],
#        [14,  8],
#        [ 3, 14],
#        [15, 16],
#        [14,  6],
#        [ 8, 14],
#        [ 3, 12],
#        [ 9, 20],
#        [ 2,  1],
#        [24,  2],
#        [24, 12],
#        [19, 17],
#        [14, 20],
#        [ 1, 18],
#        [ 0,  9],
#        [22,  2],
#        [14,  5],
#        [12,  2],
#        [21, 18],
#        [12,  0],
#        [24, 12]])
